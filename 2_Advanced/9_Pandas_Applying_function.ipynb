# %%
from datasets import load_dataset
import matplotlib.pyplot as plt
import pandas as pd

# %%
my_dataset=load_dataset('lukebarousse/data_jobs')

# %%
df=my_dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_date']
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
df['salary_year_avg']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_year_avg, Length: 785741, dtype: float64

# %%
df_salary=df[pd.notna(df['salary_year_avg'])].copy()

# %%
df_salary['salary_year_inflated']=df_salary['salary_year_avg'].apply(lambda salary:salary*1.03)

# %%
df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
import ast
type(ast.literal_eval(df['job_skills'][1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 2
#       1 import ast
# ----> 2 type(ast.literal_eval(df['job_skills'][1]))
#
# File c:\Users\FAIZAN AKHTAR\anaconda3\envs\pthon_data_project\Lib\ast.py:112, in literal_eval(node_or_string)
#     110                 return left - right
#     111     return _convert_signed_num(node)
# --> 112 return _convert(node_or_string)
#
# File c:\Users\FAIZAN AKHTAR\anaconda3\envs\pthon_data_project\Lib\ast.py:111, in literal_eval.<locals>._convert(node)
#     109         else:
#     110             return left - right
# --> 111 return _convert_signed_num(node)
#
# File c:\Users\FAIZAN AKHTAR\anaconda3\envs\pthon_data_project\Lib\ast.py:85, in literal_eval.<locals>._convert_signed_num(node)
#      83     else:
#      84         return - operand
# ---> 85 return _convert_num(node)
#
# ...

# %%
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)

# %%
df['job_skills']=df['job_skills'].apply(clean_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df['job_skills']=df['job_skills'].apply(clean_list)
#
# File c:\Users\FAIZAN AKHTAR\anaconda3\envs\pthon_data_project\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
type(df['job_skills'][1])
# Out:
# list

# %%
##df['job_skills']=df['job_skills'].apply(lambda skill_test: ast.literal_eval(skill_test) if pd.notna(skill_test) else skill_test)

# %%
df_salary
# Out:
#        job_title_short  ... salary_year_inflated
# 28      Data Scientist  ...            112785.00
# 77       Data Engineer  ...            144200.00
# 92       Data Engineer  ...            123600.00
# 100     Data Scientist  ...            235068.66
# 109       Data Analyst  ...             91670.00
# ...                ...  ...                  ...
# 785624   Data Engineer  ...            143392.48
# 785641   Data Engineer  ...            154500.00
# 785648  Data Scientist  ...            228531.25
# 785682  Data Scientist  ...            162225.00
# 785692  Data Scientist  ...            162225.00
#
# [22003 rows x 18 columns]

# %%
def projected_salary(salary):
    if "Senior" in salary['job_title_short']:
        return 1.05 * salary['salary_year_avg']
    else:
        return 1.03 * salary['salary_year_avg']

df_salary['salary_year_inflated']=df_salary.apply(projected_salary, axis=1)

# %%
df_salary[['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]
