# %%
from datasets import load_dataset
import pandas as pd
import matplotlib.pyplot as plt

# %%
my_dataset=load_dataset('lukebarousse/data_jobs')

# %%
df=my_dataset['train'].to_pandas()

# %%
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df
# Out:
#              job_title_short  ...                                    job_type_skills
# 0       Senior Data Engineer  ...                                               None
# 1               Data Analyst  ...  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2              Data Engineer  ...  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3              Data Engineer  ...  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4              Data Engineer  ...  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                      ...  ...                                                ...
# 785736     Software Engineer  ...  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737          Data Analyst  ...  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738      Business Analyst  ...         {'analyst_tools': ['powerpoint', 'excel']}
# 785739         Data Engineer  ...  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# ...

# %% [markdown]
# ##Creating month from job_posted_date

# %%
df['job_posted_month']=df['job_posted_date'].dt.strftime('%b')

# %%
df
# Out:
#              job_title_short  ... job_posted_month
# 0       Senior Data Engineer  ...              Jun
# 1               Data Analyst  ...              Jan
# 2              Data Engineer  ...              Oct
# 3              Data Engineer  ...              Jul
# 4              Data Engineer  ...              Aug
# ...                      ...  ...              ...
# 785736     Software Engineer  ...              Mar
# 785737          Data Analyst  ...              Mar
# 785738      Business Analyst  ...              Mar
# 785739         Data Engineer  ...              Mar
# 785740     Software Engineer  ...              Mar
#
# [785741 rows x 18 columns]

# %% [markdown]
# ## Extracting month from datetime formst

# %%
months=df['job_posted_month'].unique()

# %%
months
# Out:
# array(['Jun', 'Jan', 'Oct', 'Jul', 'Aug', 'Nov', 'Mar', 'Dec', 'Apr',
#        'Feb', 'Sep', 'May'], dtype=object)

# %%
dict_months={month:df[df['job_posted_month']==month] for month in months}

# %%
dict_months['Jan']
# Out:
#           job_title_short  ... job_posted_month
# 1            Data Analyst  ...              Jan
# 20         Data Scientist  ...              Jan
# 39          Data Engineer  ...              Jan
# 53          Data Engineer  ...              Jan
# 55         Data Scientist  ...              Jan
# ...                   ...  ...              ...
# 785699  Software Engineer  ...              Jan
# 785700      Data Engineer  ...              Jan
# 785703       Data Analyst  ...              Jan
# 785704   Business Analyst  ...              Jan
# 785705       Data Analyst  ...              Jan
#
# [91822 rows x 18 columns]

# %%
df_q1=pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar'], dict_months['Apr'] ], ignore_index=True)

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df_q1.to_excel('quarter1.xlsx')

# %%
pd.read_csv('quarter1.csv', index_col=0)
# Out:
#           job_title_short  ... job_posted_month
# 0            Data Analyst  ...              Jan
# 1          Data Scientist  ...              Jan
# 2           Data Engineer  ...              Jan
# 3           Data Engineer  ...              Jan
# 4          Data Scientist  ...              Jan
# ...                   ...  ...              ...
# 283398  Software Engineer  ...              Apr
# 283399     Data Scientist  ...              Apr
# 283400  Software Engineer  ...              Apr
# 283401     Data Scientist  ...              Apr
# 283402   Business Analyst  ...              Apr
#
# [283403 rows x 18 columns]
